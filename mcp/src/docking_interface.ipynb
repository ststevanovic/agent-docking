# %% [markdown]
# # Create a .env file with your credentials
# MONGODB_URI="your_mongodb_uri"
# MONGODB_DB="docking_db"
# MONGODB_VECTOR_COLL="docking_params"
# MONGODB_VECTOR_INDEX="docking_index"
# OPENAI_API_KEY="your_openai_key"
